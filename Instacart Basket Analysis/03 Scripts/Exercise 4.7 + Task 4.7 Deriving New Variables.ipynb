# %% [markdown]
# # 01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Defining the path
path = r'C:\Users\Admin\2nd-OCT-2023 Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\Admin\\2nd-OCT-2023 Instacart Basket Analysis'

# %%
# Import ords_prods_merged data set
ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
# create a subset
df = ords_prods_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 16)

# %% [markdown]
# # If-Statements with User-Defined Functions

# %%
# create price_label function
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# apply the function
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11252\2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df
# Out:
#         order_id  user_id  order_number  orders_day_of_week  \
# 0        2539329        1             1                   2
# 1        2398795        1             2                   3
# 2         473747        1             3                   3
# 3        2254736        1             4                   4
# 4         431534        1             5                   4
# ...          ...      ...           ...                 ...
# 999995   2836489   164627            14                   0
# 999996   1843600   164632             5                   1
# 999997    733106   164632             9                   2
# 999998   1650124   164632            17                   6
# 999999   3378258   164632            22                   6
#
#         order_hour_of_day  days_since_prior_orde  product_id  \
# 0                       8                    NaN         196
# 1                       7                   15.0         196
# ...

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    756450
# Low-range product    243550
# Name: count, dtype: int64

# %%
# check most expensive product price within the subset
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# # If-Statements with the loc() Function

# %%
# create price label using loc function
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11252\1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product    756450
# Low-range product    243550
# Name: count, dtype: int64

# %%
# create price label for entire ords_prods_merged dataframe using loc function
ords_prods_merged.loc[ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merged.loc[(ords_prods_merged['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merged.loc[ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# NaN                   21133696
# Low-range product     10126384
# Mid-range product       756450
# High-range product      417682
# Name: count, dtype: int64

# %% [markdown]
# # If-Statements with For-Loops

# %%
# Count the number of orders per day of the week
ords_prods_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6209632
# 1    5665830
# 6    4500246
# 2    4217766
# 5    4209449
# 3    3844096
# 4    3787193
# Name: count, dtype: int64

# %%
# Set loop
result = []

for value in ords_prods_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Add result to dataframe
ords_prods_merged['busiest_day'] = result

# %%
# Check value counts
ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22437387
# Busiest day        6209632
# Least busy         3787193
# Name: count, dtype: int64

# %% [markdown]
# # Task 4.7

# %% [markdown]
# # Q2. Create a new column for busiest days using a suitable method

# %%
# Create new if-statement for-loop for new requirements
result_2 = []

for value in ords_prods_merged["orders_day_of_week"]:
  if value == 0 or value == 1:
    result_2.append("Busiest days")
  elif value == 4 or value == 3:
    result_2.append("Least busy days")
  else:
    result_2.append("Regularly busy days")

# %%
# Add result to dataframe in new column
ords_prods_merged['busiest_days'] = result_2

# %%
# Check dataframe
ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_orde  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %% [markdown]
# # Q3. Check the values of this new column for accuracy. Note any observations in markdown format.

# %%
# Check value counts
ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# busiest_days
# Regularly busy days    12927461
# Busiest days           11875462
# Least busy days         7631289
# Name: count, dtype: int64

# %% [markdown]
# When checked with our original frequency counts, these values add up to the sums of each "grouping". ie - the total for busiest days equals the sum of value 0 and value 1, and the values for least busy days adds to the sum of value 3 and 4, confirming that the loop operated correctly.

# %% [markdown]
# # Q4. Identify the busiest hours of the day  by periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.”  Create a new column containing these labels called “busiest_period_of_day.”

# %%
# Check frequency of values in the "order_hour_of_day" column 
ords_prods_merged['order_hour_of_day'].value_counts()
# Out:
# order_hour_of_day
# 10    2764390
# 11    2738585
# 14    2691563
# 15    2664522
# 13    2663272
# 12    2620800
# 16    2537469
# 9     2456661
# 17    2089452
# 8     1719952
# 18    1637922
# 19    1259382
# 20     977017
# 7      891928
# 21     796362
# 22     634737
# 23     402612
# 6      290770
# 0      218942
# 1      115786
# 5       88057
# 2       69431
# 4       53283
# 3       51317
# Name: count, dtype: int64

# %% [markdown]
# group the 24 hours of the day into three equal groups of 8 hours as follows: Most orders (10,11,14,15,13,12,16,9), Average orders (17,8,18,19,20,7,21,22), Fewest orders (23,6,0,1,5,2,4,3)

# %%
# Create a for-loop if statement using the above breakdown
hour_of_day = []

for value in ords_prods_merged["order_hour_of_day"]:
  if value in [10, 11, 14, 15, 13, 12, 16, 9]:
    hour_of_day.append("Most orders")
  elif value in [23, 6, 0, 1, 5, 2, 4, 3]:
    hour_of_day.append("Fewest orders")
  else:
    hour_of_day.append("Average orders")

# %%
# Add result to dataframe as "busiest_period_of_day" column
ords_prods_merged['busiest_period_of_day'] = hour_of_day

# %%
# Check dataframe for new column
ords_prods_merged[['order_hour_of_day', 'busiest_period_of_day']].head(10)
# Out:
#    order_hour_of_day busiest_period_of_day
# 0                  8        Average orders
# 1                  7        Average orders
# 2                 12           Most orders
# 3                  7        Average orders
# 4                 15           Most orders
# 5                  7        Average orders
# 6                  9           Most orders
# 7                 14           Most orders
# 8                 16           Most orders
# 9                  8        Average orders

# %% [markdown]
# # Q5. Print the frequency for this new column.

# %%
ords_prods_merged['busiest_period_of_day'].value_counts()
# Out:
# busiest_period_of_day
# Most orders       21137262
# Average orders    10006752
# Fewest orders      1290198
# Name: count, dtype: int64

# %% [markdown]
# # Q6. Ensure your notebook is clean and structured and that your code is well commented.

# %% [markdown]
# The notebook is clean, structured and well commented.

# %% [markdown]
# # Q7. Export your dataframe as a pickle file.

# %%
# Export the updated dataframe as a pickle file
ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_updated.pkl'))
